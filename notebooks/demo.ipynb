# %%
# %matplotlib qt
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
# from cogent_analysis_dcp import COGENTDataset
from pycogent import read_cogent_dataset

# %%
ds = read_cogent_dataset("/Users/power8/Documents/01_code/10_COGENT_fork/cogent_runs/3species_conduct_lim_CLS_hires_cons3_lores/data")

# %%
ds.cogent.plot(["Te","Ti"],t=[10,11,12],same_axes=True)

# %%
ds.cogent.animate(ds["ne"] + ds["ni"], same_axes=True)

# %%
ds["ne"] - ds["ni"]
